# %% [markdown]
# ### 0. 이 영상들에 대하여...
#
# - 약 25 회
#
# - 흔히 파이썬이 비전공자도 조금만 하면 대기업 코딩테스트에 다 붙을 수 있고, 마스터할 수 있는 언어라는 것에 대한 오해를 풀고자 함
#
# - 그럼에도 파이썬은 '배우기' 쉽고, 자료를 찾아 '적용하기' 쉽다.
#
# - 배워두면 스펙으로 좋다. 예를 들면 자동화 프로그래밍을 해서 논다거나...
#
# - 제 구독자가 되어, 저를 도와주세요. 열심히 할게요!

# %% [markdown]
# # 파이썬 알아보기

# %% [markdown]
# ### 1. 파이썬의 개발자
# - 귀도 반 로섬(Guido van Rossum)
#
#     - 1956년 1월 31일 생
#
#     - 네덜란드 출신의 컴퓨터 프로그래머
#
#     - 2005년 ~ 2012년 : 구글
#
#       2013년 ~ 2019년 : 드롭박스
#
#       2020년 ~        : 마이크로소프트
#
#     - 1989년 크리스마스 연휴 기간 동안 '취미'로 파이썬을 제작, 1991년 배포
#
#         - 유사 사례 : flask 웹 프레임워크 -> 만우절에 그 당시 유행하던 '마이크로 웹 프레임워크'라는 것을 조롱하려고 장난으로 웹 페이지를 만들었다가 반응이 좋아서 진짜 개발

# %%
import requests
from io import BytesIO
from PIL import Image

# %%
Image.open(BytesIO(requests.get(
    'https://steemitimages.com/0x0/https://cdn.steemitimages.com/DQmVZBp5QTJqwpv4pwBz7xysxumXNiu8uDnW5pdszQz8QqZ/image.png').content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x960>

# %% [markdown]
# * 이름의 유래
#
#     - 당시 귀도님이 즐겨보시던 TV프로그램 'Monty Python's Flying Circus'에서 따온 것
#
#     - Monty Python
#
#         : 영국 대표 코미디 그룹...사람이 아님
#
#         : 몸개그, 드립, 블랙 코미디 등등 모든 개그 장르 섭렵
#
#         : 개그계의 비틀즈로 불렸을 정도로 영향력이 대단했다고 함
#
#     - 근데 막상 로고는 뱀

# %%
Image.open(BytesIO(requests.get(
    'https://www.oregonlive.com/resizer/ofwURcn7r6xROw2aBJupllzQ6FY=/1280x0/smart/image.oregonlive.com/home/olive-media/width600/img/tv/photo/2018/10/10/montycastjpg-7ef393e2355a42aa.jpg').content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x960>
